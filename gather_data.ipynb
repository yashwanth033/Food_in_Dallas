# %% [markdown]
# # Yelp API - Gathering Data
#
# ## In this Notebook:
#  - Using YELP Fusion API, restaurant information from Dallas (within 25 miles of Dallas, TX) was saved

# %% [markdown]
# ### Using offset and limit parameters in Yelp API
#
# There is a limit of 50 places per API call, offset and limit parameters allow a total of 1000 places to be called.
#
# Example:
# with OFFSET = 50, LIMIT = 50,
# you will receive results 51-100
#
#
# ### Steps taken to retrieve data
#
# - Get maximum of 1000 restaurants within 25 miles of Dallas, Texas

# %% [markdown]
# ## Testing endpoint

# %%
import requests

API_KEY = 'eVBCTWO_MZ8g57v8-zOVL9Nm-UqUOrEg_0g43WNdxFcsXFA8SRNKflKrRaCN5iRwZnWdpMgpVoltFUEjc0SaUi65y6Y7VANNLVn8TKNNhIEc3LqoUNRIYRIbwYKJYXYx'
CLIENT_ID = 'zC-Jrqxt7h6piT-XMntPwg'

ENDPOINT = "https://api.yelp.com/v3/businesses/search"

HEADERS = {'Authorization': 'bearer %s' % API_KEY}

PARAMETERS = {'term': 'restaurants',
              'offset': 0,
              'limit': 50,
              'radius': 40000,
              'location': 'Dallas, TX'}

response = requests.get(url=ENDPOINT, params=PARAMETERS, headers=HEADERS)

# %% [markdown]
# ## Next, let's gather the data for all restaurants within a radius of 40,000 m (or 25 miles) from Dallas, TX

# %%
import json

# %%
import time

PARAMETERS = {'term': 'restaurants',
              'offset': 0, # start at 0
              'limit': 50, # maximum is 50
              'radius': 40000, # in m
              'location': 'Dallas, TX'}

restaurants_in_dallas = []


# Cycle through restaurants
for offset_number in range(0,1000,50):
    PARAMETERS['offset'] = offset_number

    response = requests.get(url=ENDPOINT, params=PARAMETERS, headers=HEADERS)

    if not response.json().get('businesses', False):
        break

    restaurants_in_dallas.extend(response.json()['businesses'])

    print("{}-{}".format(offset_number, offset_number+50))

    time.sleep(0.5) ## Don't want to get blocked by Yelp API
# Out:
# 0-50
# 50-100
# 100-150
# 150-200

# %%
restaurants_in_dallas
# Out:
# [{'id': '2jxPJngbOs5YU7keUJ1LyA',
#   'alias': 'hawaiian-bros-island-grill-dallas',
#   'name': 'Hawaiian Bros Island Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IEiM4a4EcWxY193rvpotyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hawaiian-bros-island-grill-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 15,
#   'categories': [{'alias': 'hawaiian', 'title': 'Hawaiian'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.8586594, 'longitude': -96.76862},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '6011 Greenville Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['6011 Greenville Ave', 'Dallas, TX 75206']},
#   'phone': '+12142068646',
#   'display_phone': '(214) 206-8646',
#   'distance': 3694.210297188993},
#  {'id': '9uaSZzLB7CEHGc4mokQxig',
#   'alias': 'the-porch-dallas',
#   'name': 'The Porch',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZwkvZQNkJjUHSPdkPjvCbQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-porch-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 1450,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.82064248039, 'longitude': -96.784746955887},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2912 N Henderson Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2912 N Henderson Ave', 'Dallas, TX 75206']},
#   'phone': '+12148282916',
#   'display_phone': '(214) 828-2916',
#   'distance': 2522.53565678719},
#  {'id': 'bml-gjgOTeSYJI-Gq6bMRA',
#   'alias': 'monarch-dallas',
#   'name': 'Monarch',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eM-zwNrhF-3Zq-K075M6sQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/monarch-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 260,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.781565163451, 'longitude': -96.8006905},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '1401 Elm St',
#    'address2': 'Fl 49',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75202',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1401 Elm St', 'Fl 49', 'Dallas, TX 75202']},
#   'phone': '+12149452222',
#   'display_phone': '(214) 945-2222',
#   'distance': 6391.306446862011},
#  {'id': 'CREIs-59rrp8OhG9VppCqA',
#   'alias': 'ellens-dallas-4',
#   'name': "Ellen's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3xh0YLJvSgZDW8qR7zgKkw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ellens-dallas-4?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 2843,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.7818955295251,
#    'longitude': -96.8076125410698},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1790 N Record St',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75202',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1790 N Record St', 'Dallas, TX 75202']},
#   'phone': '+14692063339',
#   'display_phone': '(469) 206-3339',
#   'distance': 6388.8661678353365},
#  {'id': 'qtOSR7WS36sbAQi0ySSuEg',
#   'alias': 'r-d-kitchen-dallas',
#   'name': 'R+D Kitchen',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0uzVTw-7qDCFc1Kz4ptOsA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/r-d-kitchen-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 547,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.863065, 'longitude': -96.802789},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '8300 Preston Ctr Plz',
#    'address2': '',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75225',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8300 Preston Ctr Plz', 'Dallas, TX 75225']},
#   'phone': '+12148907900',
#   'display_phone': '(214) 890-7900',
#   'distance': 2679.338235120256},
#  {'id': '_HSm-dvSgWKQinYIhvGyZg',
#   'alias': 'son-of-a-butcher-dallas',
#   'name': 'Son of a Butcher',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2mIU7zdtedP3SXZieyVMHQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/son-of-a-butcher-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 181,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.81463899768355, 'longitude': -96.7699067},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2026 Greenville Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2026 Greenville Ave', 'Dallas, TX 75206']},
#   'phone': '+14698628780',
#   'display_phone': '(469) 862-8780',
#   'distance': 3944.0176162714806},
#  {'id': 'gsHF1u6AQGm69AXGw0c8zw',
#   'alias': 'palmers-hot-chicken-dallas-2',
#   'name': "Palmer's Hot Chicken",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DWgd2TAQB96znq6PgTuVFg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/palmers-hot-chicken-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 179,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.83792397323037,
#    'longitude': -96.75208473475357},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6465 E Mockingbird Ln',
#    'address2': 'Ste 316',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75214',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['6465 E Mockingbird Ln',
#     'Ste 316',
#     'Dallas, TX 75214']},
#   'phone': '+19728639366',
#   'display_phone': '(972) 863-9366',
#   'distance': 4528.430528807112},
#  {'id': '-igPjFytiwYK1GLdg62iqg',
#   'alias': 'anise-dallas',
#   'name': 'Anise',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XYEbqZnRZw7pevVBmaX0Mw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/anise-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 10,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.85949931, 'longitude': -96.76337199},
#   'transactions': ['delivery'],
#   'location': {'address1': '5630 Village Glen Dr',
#    'address2': None,
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5630 Village Glen Dr', 'Dallas, TX 75206']},
#   'phone': '+14696596376',
#   'display_phone': '(469) 659-6376',
#   'distance': 4150.5330917357},
#  {'id': 'BfWS6DGpr6fcNiEt47XU6w',
#   'alias': 'loro-dallas-2',
#   'name': 'Loro',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RonNWcFqQTm8bmgTkrgwfA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/loro-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 159,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.80118333196168,
#    'longitude': -96.78474583327278},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1812 N Haskell Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75204',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1812 N Haskell Ave', 'Dallas, TX 75204']},
#   'phone': '+12148334983',
#   'display_phone': '(214) 833-4983',
#   'distance': 4460.977269719827},
#  {'id': 'U3Nx-Vvizc6BMHiZxcuw7A',
#   'alias': 'il-bracco-dallas',
#   'name': 'il Bracco',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_HbsDIHELS73csuQzlf7Jg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/il-bracco-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 155,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.864895, 'longitude': -96.802592},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '8416 Preston Center Plaza Dr',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75225',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8416 Preston Center Plaza Dr', 'Dallas, TX 75225']},
#   'phone': '+12143610100',
#   'display_phone': '(214) 361-0100',
#   'distance': 2882.095939975006},
#  {'id': 'Z9YD1_NlR-3xYRqmX2hVWw',
#   'alias': 'hudson-house-dallas',
#   'name': 'Hudson House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7vEM3UkcbTp-I2o87bh3jw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hudson-house-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 430,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.8514422143352,
#    'longitude': -96.8116955048394},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '4448 Lovers Ln',
#    'address2': '',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75225',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['4448 Lovers Ln', 'Dallas, TX 75225']},
#   'phone': '+12145832255',
#   'display_phone': '(214) 583-2255',
#   'distance': 1728.3967000248024},
#  {'id': 'BrrMLIT1F3GbzAt233ZqAQ',
#   'alias': 'tequila-delicious-dallas',
#   'name': 'Tequila Delicious',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AH78PPwcLa6rEd-Xl5rRQg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tequila-delicious-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 10,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.79683, 'longitude': -96.79719},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '2901 Thomas Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75204',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2901 Thomas Ave', 'Dallas, TX 75204']},
#   'phone': '+12149659595',
#   'display_phone': '(214) 965-9595',
#   'distance': 4704.124554674272},
#  {'id': 'bPSOKiR5naMHfx0myab8qQ',
#   'alias': 'hungry-belly-dallas',
#   'name': 'Hungry Belly',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GOYFcarpLlvYvevwXW1W6A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hungry-belly-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 322,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.815481, 'longitude': -96.787098616813},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2818 N Fitzhugh Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75204',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2818 N Fitzhugh Ave', 'Dallas, TX 75204']},
#   'phone': '+12142585859',
#   'display_phone': '(214) 258-5859',
#   'distance': 2905.3794452394964},
#  {'id': '1PlCn1i8g1Hsd-gYkFw_3w',
#   'alias': 'sister-restaurant-dallas',
#   'name': 'Sister Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8_Oh7iZqsj_AQXlyzp08qA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sister-restaurant-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 9,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 32.82347, 'longitude': -96.76995},
#   'transactions': [],
#   'location': {'address1': '2808 Greenville Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2808 Greenville Ave', 'Dallas, TX 75206']},
#   'phone': '+12148888660',
#   'display_phone': '(214) 888-8660',
#   'distance': 3343.671786664083},
#  {'id': 'etRHibg199HuOeXUNmYWXA',
#   'alias': 'sixty-vines-dallas',
#   'name': 'Sixty Vines',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W_orrQC2nsgaORncwYQXog/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sixty-vines-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 1051,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.79421, 'longitude': -96.80409},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '500 Crescent Ct',
#    'address2': 'Ste 160',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75201',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['500 Crescent Ct', 'Ste 160', 'Dallas, TX 75201']},
#   'phone': '+12148148463',
#   'display_phone': '(214) 814-8463',
#   'distance': 4903.416781830359},
#  {'id': 'vwQnJlj90NgYbbbVLQSpFg',
#   'alias': 'meso-maya-comida-y-copas-dallas-4',
#   'name': 'Meso Maya Comida y Copas',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Pnvf5VP0DYuT0CTz2EUZ2A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/meso-maya-comida-y-copas-dallas-4?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 2444,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'newmexican', 'title': 'New Mexican Cuisine'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.7877819354234,
#    'longitude': -96.8049378803092},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1611 McKinney Ave',
#    'address2': 'Dallas',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75202',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1611 McKinney Ave', 'Dallas', 'Dallas, TX 75202']},
#   'phone': '+12144846555',
#   'display_phone': '(214) 484-6555',
#   'distance': 5714.834942242468},
#  {'id': 'FlyoRMsduth2VO_HnXHeJw',
#   'alias': 'tricky-fish-dallas',
#   'name': 'Tricky Fish',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7cigNLTzw4ijppkUgrSG7w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tricky-fish-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 22,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.88028, 'longitude': -96.77248},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '7859 Walnut Hill Ln',
#    'address2': 'Ste 170',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75230',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['7859 Walnut Hill Ln', 'Ste 170', 'Dallas, TX 75230']},
#   'phone': '+12142104844',
#   'display_phone': '(214) 210-4844',
#   'distance': 5321.081270111821},
#  {'id': 'WQQ6LkZeqax97-CrDdK2fQ',
#   'alias': 'ngon-vietnamese-kitchen-dallas-2',
#   'name': 'Ngon Vietnamese Kitchen',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ifu6Q9dJ-0yY2TcWZsa0ug/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ngon-vietnamese-kitchen-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 221,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.813718, 'longitude': -96.770578},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1907 Greenville Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1907 Greenville Ave', 'Dallas, TX 75206']},
#   'phone': '+14692507183',
#   'display_phone': '(469) 250-7183',
#   'distance': 3973.4086913419515},
#  {'id': '5oh7oB7Yoc3M0ofVaiKiAw',
#   'alias': 'rh-rooftop-restaurant-dallas-dallas',
#   'name': 'RH Rooftop Restaurant Dallas',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4UxxonzuqDcqFuY1dpDVTA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rh-rooftop-restaurant-dallas-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 100,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 32.8227922, 'longitude': -96.7885325},
#   'transactions': [],
#   'location': {'address1': '3133 Knox St',
#    'address2': None,
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75205',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3133 Knox St', 'Dallas, TX 75205']},
#   'phone': '+12145207255',
#   'display_phone': '(214) 520-7255',
#   'distance': 2129.2713867200046},
#  {'id': 'LiYys5glM0MO2A9rCkcFWA',
#   'alias': 'xoxo-dining-room-dallas',
#   'name': 'XOXO Dining Room',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vty6dUkhwHsCN08U72eOqQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/xoxo-dining-room-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 474,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 32.794171, 'longitude': -96.791056},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '3121 Ross Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75204',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3121 Ross Ave', 'Dallas, TX 75204']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 5064.509073166626},
#  {'id': 'BmX-t6hhACCc60h0jhj2XA',
#   'alias': 'k-pop-ramen-dallas',
#   'name': 'K Pop Ramen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ngLT0V2FeBjpu3qPYMkx5g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/k-pop-ramen-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 152,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.825176, 'longitude': -96.819912},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5150 Lemmon Ave',
#    'address2': 'Ste 104',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75209',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5150 Lemmon Ave', 'Ste 104', 'Dallas, TX 75209']},
#   'phone': '+19726853033',
#   'display_phone': '(972) 685-3033',
#   'distance': 2382.275088488905},
#  {'id': 'd9binwgfwGvijxZAH2r6NA',
#   'alias': 'the-honor-bar-dallas',
#   'name': 'The Honor Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/backdkFfaCinrzQc_rL9wA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-honor-bar-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 223,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.835492, 'longitude': -96.806765},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '26A Highland Park Village',
#    'address2': '',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75205',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['26A Highland Park Village', 'Dallas, TX 75205']},
#   'phone': '+12147800956',
#   'display_phone': '(214) 780-0956',
#   'distance': 703.2121353479548},
#  {'id': 'ycL1qii6EpKXoLgMMboBIQ',
#   'alias': 'pecan-lodge-dallas-3',
#   'name': 'Pecan Lodge',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9aPP6Dp7IDXh6cjLlp33cg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pecan-lodge-dallas-3?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 5424,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'southern', 'title': 'Southern'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.78371943063679,
#    'longitude': -96.78386072987722},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2702 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75226',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2702 Main St', 'Dallas, TX 75226']},
#   'phone': '+12147488900',
#   'display_phone': '(214) 748-8900',
#   'distance': 6346.090814739491},
#  {'id': 'hOz71frjP1qEPKW74ckGqg',
#   'alias': 'drake-s-hollywood-dallas',
#   'name': "Drake's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MAXK0n5AOE-im_8_dTUGhw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/drake-s-hollywood-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 299,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#    {'alias': 'lounges', 'title': 'Lounges'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.8515865181205,
#    'longitude': -96.8249537295182},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '5007 W Lovers Ln',
#    'address2': '',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75209',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5007 W Lovers Ln', 'Dallas, TX 75209']},
#   'phone': '+12146514114',
#   'display_phone': '(214) 651-4114',
#   'distance': 2673.5919771475233},
#  {'id': 'bULVB0Q87mn4u2sNPjXTTQ',
#   'alias': 'rodeo-goat-dallas',
#   'name': 'Rodeo Goat',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qpdC5Q9ImVZj_e6EL_lMRA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rodeo-goat-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 2251,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.7971504231268,
#    'longitude': -96.8239863214264},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1926 Market Center Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75207',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1926 Market Center Blvd', 'Dallas, TX 75207']},
#   'phone': '+12147414628',
#   'display_phone': '(214) 741-4628',
#   'distance': 5147.945817852955},
#  {'id': 'z9Np1GqYDydvm7g5OTyoYg',
#   'alias': 'marugame-udon-dallas-2',
#   'name': 'Marugame Udon',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/a1h7hObsJ6e684Ef62f6KQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/marugame-udon-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 107,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.855045044880235,
#    'longitude': -96.76855356349093},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '5500 Greenville Ave',
#    'address2': 'Ste 1102',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5500 Greenville Ave', 'Ste 1102', 'Dallas, TX 75206']},
#   'phone': '+14695051118',
#   'display_phone': '(469) 505-1118',
#   'distance': 3477.483772664377},
#  {'id': '0gLC14OVMWWwB9HodCF0sA',
#   'alias': 'gemma-dallas',
#   'name': 'Gemma',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gre1gJ1yd1PRIm6RFF5GPg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gemma-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 515,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.8138516520667,
#    'longitude': -96.7779396392554},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '2323 N Henderson Ave',
#    'address2': 'Ste 109',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2323 N Henderson Ave', 'Ste 109', 'Dallas, TX 75206']},
#   'phone': '+12143709426',
#   'display_phone': '(214) 370-9426',
#   'distance': 3507.85929974142},
#  {'id': 'ON9DQYtZJ4z8dZM6MEWIAw',
#   'alias': 'haywire-dallas-2',
#   'name': 'Haywire',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xCvReT4VuXvQYJaUH65gkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/haywire-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 92,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.79014, 'longitude': -96.80329},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1920 McKinney Ave',
#    'address2': 'Ste 100',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75201',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1920 McKinney Ave', 'Ste 100', 'Dallas, TX 75201']},
#   'phone': '+14695015522',
#   'display_phone': '(469) 501-5522',
#   'distance': 5446.6683081016945},
#  {'id': 'j6j8IFLUUQA1WgwGqawtkw',
#   'alias': 'rise-n-1-dallas',
#   'name': 'rise n°1',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vYSTO7Xw2Gq4ztewy6OwEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rise-n-1-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 1541,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.8501283339466,
#    'longitude': -96.8201696447052},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '5360 W Lovers Ln',
#    'address2': 'Ste 220',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75209',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5360 W Lovers Ln', 'Ste 220', 'Dallas, TX 75209']},
#   'phone': '+12143669900',
#   'display_phone': '(214) 366-9900',
#   'distance': 2209.761827649162},
#  {'id': 'rtX0x3PGCsg5TA4-ZU8J9g',
#   'alias': 'tulum-dallas',
#   'name': 'Tulum',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F-qKjDQA3vTXALL2Z4XOpg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tulum-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 203,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.8202517, 'longitude': -96.8022451},
#   'transactions': ['delivery'],
#   'location': {'address1': '4216 Oak Lawn Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75219',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['4216 Oak Lawn Ave', 'Dallas, TX 75219']},
#   'phone': '+19726779747',
#   'display_phone': '(972) 677-9747',
#   'distance': 2102.4917619059747},
#  {'id': 'uSAR3C68Du6QL1hZVtJhwA',
#   'alias': 'the-peoples-last-stand-dallas-3',
#   'name': "The People's Last Stand",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M6GDFB8ixkrCyqqOUogznw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-peoples-last-stand-dallas-3?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 346,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.8368102, 'longitude': -96.7774467},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '5319 E Mockingbird Ln',
#    'address2': 'Ste 210',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5319 E Mockingbird Ln',
#     'Ste 210',
#     'Dallas, TX 75206']},
#   'phone': '+12143708755',
#   'display_phone': '(214) 370-8755',
#   'distance': 2258.864158578376},
#  {'id': 'hxaF0VX5oB08q_TXY8LuTQ',
#   'alias': 'tejas-taco-factory-dallas-2',
#   'name': 'Tejas Taco Factory',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/92b_ZXkt8awPRofTyFaVyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tejas-taco-factory-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 13,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#    {'alias': 'tex-mex', 'title': 'Tex-Mex'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.782106761403476,
#    'longitude': -96.80521743723189},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '1001 Ross Ave',
#    'address2': 'Ste 100',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75202',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1001 Ross Ave', 'Ste 100', 'Dallas, TX 75202']},
#   'phone': '+14694669729',
#   'display_phone': '(469) 466-9729',
#   'distance': 6346.159191169399},
#  {'id': 'end4ugjsE0EWtGWswkprOA',
#   'alias': 'mami-coco-dallas-2',
#   'name': 'Mami Coco',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ru6JAt-wXinWjEg9Jn62RQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mami-coco-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 208,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 32.8003812, 'longitude': -96.777516},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '4500 Bryan St',
#    'address2': 'Ste B',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['4500 Bryan St', 'Ste B', 'Dallas, TX 75206']},
#   'phone': '+14699962834',
#   'display_phone': '(469) 996-2834',
#   'distance': 4807.241470166344},
#  {'id': 'aH3iLs5URV5sY-kNKVFyLA',
#   'alias': 'maple-leaf-diner-dallas',
#   'name': 'Maple Leaf Diner',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kZW-Jub0xRicw-d5nnYjEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/maple-leaf-diner-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 2743,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'diners', 'title': 'Diners'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.92347, 'longitude': -96.80524},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '12817 Preston Rd',
#    'address2': 'Ste 129',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75230',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['12817 Preston Rd', 'Ste 129', 'Dallas, TX 75230']},
#   'phone': '+12144341626',
#   'display_phone': '(214) 434-1626',
#   'distance': 9375.606691264125},
#  {'id': '2nz7LGrfrY5aebbyyQc14w',
#   'alias': 'yo-lobster-dallas',
#   'name': 'Yo! Lobster',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/j1hhg69h76eAfAzag81-kQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yo-lobster-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 51,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.83612747804884,
#    'longitude': -96.80656382451951},
#   'transactions': ['delivery'],
#   'location': {'address1': '33 B Highland Park Village',
#    'address2': '',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75205',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['33 B Highland Park Village', 'Dallas, TX 75205']},
#   'phone': '+12145594245',
#   'display_phone': '(214) 559-4245',
#   'distance': 649.7456732912165},
#  {'id': 'IqfMRdEX4LLchRNM98yBxQ',
#   'alias': 'hillstone-restaurant-dallas',
#   'name': 'Hillstone Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZZi6p1FxtZiwGOm-z7U24A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hillstone-restaurant-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 589,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.863086142812, 'longitude': -96.80372640714},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '8300 A Preston Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75225',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8300 A Preston Rd', 'Dallas, TX 75225']},
#   'phone': '+12146918991',
#   'display_phone': '(214) 691-8991',
#   'distance': 2689.9676343178326},
#  {'id': 'TxZWdv85JeNr7U8Q1mzsuw',
#   'alias': 'burning-rice-dallas',
#   'name': 'Burning Rice',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UDyMv3YvHAs_pkETt1mhuA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/burning-rice-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 116,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.8635550352729,
#    'longitude': -96.8062060340337},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '6106 Luther Ln',
#    'address2': '',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75225',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['6106 Luther Ln', 'Dallas, TX 75225']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2776.5239318316303},
#  {'id': 'U2AeIIGWcCwFa074GZ4GlA',
#   'alias': 'caribbean-s-shark-seafood-dallas-2',
#   'name': 'Caribbean’s Shark Seafood',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ol3uN87uWI_H95KxDZ6CkA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/caribbean-s-shark-seafood-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 68,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 32.84605, 'longitude': -96.7696},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4814 Greenville Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['4814 Greenville Ave', 'Dallas, TX 75206']},
#   'phone': '+14699140088',
#   'display_phone': '(469) 914-0088',
#   'distance': 2989.9095881414205},
#  {'id': 'Ihmg2gvybDPIUiIRcIfFmg',
#   'alias': 'royal-38-dallas',
#   'name': 'Royal 38',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gE9D16u9BxJ3zKpwqJSqyg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/royal-38-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 113,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.78948, 'longitude': -96.80563},
#   'transactions': ['delivery'],
#   'location': {'address1': '2301 N Akard St',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75201',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2301 N Akard St', 'Dallas, TX 75201']},
#   'phone': '+12147369010',
#   'display_phone': '(214) 736-9010',
#   'distance': 5562.148642314509},
#  {'id': 'EV5qTRnktTvOOwX6ZJgagA',
#   'alias': 'chimichurri-argentinian-bistro-and-bar-dallas',
#   'name': 'Chimichurri Argentinian Bistro & Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DaA0stIQOAAvGQCCw5i3Sw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chimichurri-argentinian-bistro-and-bar-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 48,
#   'categories': [{'alias': 'argentine', 'title': 'Argentine'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.748721, 'longitude': -96.827671},
#   'transactions': ['delivery'],
#   'location': {'address1': '324 W 7th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75208',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['324 W 7th St', 'Dallas, TX 75208']},
#   'phone': '+14699066098',
#   'display_phone': '(469) 906-6098',
#   'distance': 10357.270800312795},
#  {'id': 'pX8jseEF57jr-xOyh3ij9w',
#   'alias': 'yardbird-table-and-bar-dallas-2',
#   'name': 'Yardbird Table & Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QPQdeFw-ucjJaTsiLvFa4A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yardbird-table-and-bar-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 440,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.7909, 'longitude': -96.801195},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '2121 N Pearl St',
#    'address2': None,
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75201',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2121 N Pearl St', 'Dallas, TX 75201']},
#   'phone': '+14692082441',
#   'display_phone': '(469) 208-2441',
#   'distance': 5333.96545076446},
#  {'id': 'A2_8ng_vTrzRZ7UeMJxADw',
#   'alias': 'rexs-seafood-and-market-dallas-3',
#   'name': "Rex's Seafood and Market",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-3IuP6e_1r0J0ociiC_gdg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rexs-seafood-and-market-dallas-3?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 96,
#   'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.86586833, 'longitude': -96.78886333},
#   'transactions': ['delivery'],
#   'location': {'address1': '6713 W Northwest Hwy',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75225',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['6713 W Northwest Hwy', 'Dallas, TX 75225']},
#   'phone': '+12147580566',
#   'display_phone': '(214) 758-0566',
#   'distance': 3201.198537702201},
#  {'id': 'eYidMsvVzEbCZgyH1DI__w',
#   'alias': 'original-chopshop-dallas-6',
#   'name': 'Original ChopShop',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FpR0uElgJ_rB8Svqf6Tyjg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/original-chopshop-dallas-6?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 88,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.84407, 'longitude': -96.78742},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '6401 Hillcrest Ave',
#    'address2': 'Ste 100',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75205',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['6401 Hillcrest Ave', 'Ste 100', 'Dallas, TX 75205']},
#   'phone': '+19725460418',
#   'display_phone': '(972) 546-0418',
#   'distance': 1351.6700337155103},
#  {'id': '2swAF8b2CXXrfbajpKiCjA',
#   'alias': 'lucky-s-hot-chicken-dallas-2',
#   'name': 'Lucky’s Hot Chicken',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/teOLln0zBzq5UhfWwQLKIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lucky-s-hot-chicken-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 31,
#   'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 32.84311525532228, 'longitude': -96.787461},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '6309 Hillcrest Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75205',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['6309 Hillcrest Ave', 'Dallas, TX 75205']},
#   'phone': '+12144437927',
#   'display_phone': '(214) 443-7927',
#   'distance': 1302.8179844072088},
#  {'id': 'pY_HNCgc1uksUb9d25lWyQ',
#   'alias': 'fachini-dallas',
#   'name': 'Fachini',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ihNQW2OZe2occqk3SoTrXg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fachini-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 129,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.836037, 'longitude': -96.8067158},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '33A Highland Park Village',
#    'address2': '',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75205',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['33A Highland Park Village', 'Dallas, TX 75205']},
#   'phone': '+12148389688',
#   'display_phone': '(214) 838-9688',
#   'distance': 667.0728322884548},
#  {'id': 'DEbsQ0oo4s1FGfiwhKEGvQ',
#   'alias': 'taverna-dallas-2',
#   'name': 'Taverna',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yxVPaVvgRymBrAScifz9nw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taverna-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 431,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.8239874953375,
#    'longitude': -96.7907707342891},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3312 Knox St',
#    'address2': '',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75205',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3312 Knox St', 'Dallas, TX 75205']},
#   'phone': '+12145209933',
#   'display_phone': '(214) 520-9933',
#   'distance': 1906.6824766994794},
#  {'id': 'v9FdUfWaB3NoD7Qsr7rKFQ',
#   'alias': 'north-italia-dallas-4',
#   'name': 'North Italia',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mKleHCvN-17paJC8AAIZzA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/north-italia-dallas-4?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 278,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
# ...
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5219 B N Lovers Ln', 'Dallas, TX 75209']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2440.8560250407086},
#  {'id': 'IOdz8GcOx8WRKqsK2DCjfw',
#   'alias': 'nick-and-sams-dallas',
#   'name': "Nick & Sam's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/u2WGeboNIWsCXpvU57-Ong/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nick-and-sams-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 1451,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.798462335543, 'longitude': -96.8074539666488},
#   'transactions': ['delivery'],
#   'price': '$$$$',
#   'location': {'address1': '3008 Maple Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75201',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3008 Maple Ave', 'Dallas, TX 75201']},
#   'phone': '+12148717444',
#   'display_phone': '(214) 871-7444',
#   'distance': 4558.469893778069},
#  {'id': 'HoVb--ig9EZWOJwLe3ZhQA',
#   'alias': 'yolk-preston-center-dallas-3',
#   'name': 'Yolk Preston Center',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JCJ6fpGWBpiVPnUgpXY0ng/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yolk-preston-center-dallas-3?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 513,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.8638900071383,
#    'longitude': -96.8066290766001},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '8315 Westchester Dr',
#    'address2': '',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75225',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8315 Westchester Dr', 'Dallas, TX 75225']},
#   'phone': '+14693510344',
#   'display_phone': '(469) 351-0344',
#   'distance': 2820.8020588896857},
#  {'id': 'n5n3yc4RMNq8QPuJZoP_ow',
#   'alias': 'sweet-rice-dallas',
#   'name': 'Sweet Rice',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qGyBC4sKJ9MQ7BwVKT5aoA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sweet-rice-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 23,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.82654, 'longitude': -96.84698},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '2337 W Mockingbird Ln',
#    'address2': 'Ste 100',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75235',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2337 W Mockingbird Ln',
#     'Ste 100',
#     'Dallas, TX 75235']},
#   'phone': '+19728639235',
#   'display_phone': '(972) 863-9235',
#   'distance': 4552.305749568066},
#  {'id': 'VAbXbfwW1-EDv9-nHQvz5Q',
#   'alias': 'primos-mx-kitchen-dallas-2',
#   'name': "Primo's MX Kitchen",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/02JrYHe9XJfp8KEyh8ZTJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/primos-mx-kitchen-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 28,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'tex-mex', 'title': 'Tex-Mex'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 32.86687, 'longitude': -96.7871977},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '8611 Hillcrest Rd',
#    'address2': 'Ste 100',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75225',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8611 Hillcrest Rd', 'Ste 100', 'Dallas, TX 75225']},
#   'phone': '+14698869114',
#   'display_phone': '(469) 886-9114',
#   'distance': 3335.6384351300794},
#  {'id': 'kgmPMAHlFjWAILBGLUSKuw',
#   'alias': 'cane-rosso-dallas',
#   'name': 'Cane Rosso',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Pyfi7Y0YtFQjPS8pOIxT_A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cane-rosso-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 1684,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.782503, 'longitude': -96.785507},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2612 Commerce St',
#    'address2': '',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75226',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2612 Commerce St', 'Dallas, TX 75226']},
#   'phone': '+12147411188',
#   'display_phone': '(214) 741-1188',
#   'distance': 6442.009813414365},
#  {'id': '8EbjBG_26PsSn6lj9yvpVg',
#   'alias': 'bubbas-cooks-country-dallas-dallas',
#   'name': "Bubba's Cooks Country - Dallas",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wEcHF7GWIrLDYHXzIcizAw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bubbas-cooks-country-dallas-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 594,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.8472817, 'longitude': -96.7870149},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '6617 Hillcrest Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75205',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['6617 Hillcrest Ave', 'Dallas, TX 75205']},
#   'phone': '+12143736527',
#   'display_phone': '(214) 373-6527',
#   'distance': 1559.9482171310597},
#  {'id': 'ZSHH7EMKanTvDhA-fjWX9A',
#   'alias': 'nawlins-dallas',
#   'name': "N'awlins",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SSmAQjSvcYVl11NEq9dOGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nawlins-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 30,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 32.79542, 'longitude': -96.81611},
#   'transactions': [],
#   'location': {'address1': '1400 Hi Line Dr',
#    'address2': 'Unit 116',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75207',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1400 Hi Line Dr', 'Unit 116', 'Dallas, TX 75207']},
#   'phone': '+14692508080',
#   'display_phone': '(469) 250-8080',
#   'distance': 5086.2700893576775},
#  {'id': 'jCjIP-pgb1F_QNvIWnq9Aw',
#   'alias': 'sandoitchi-dallas-2',
#   'name': 'Sandoitchi',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KdIXqWr1WUYS1_oD3HhKGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sandoitchi-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 62,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 32.784749, 'longitude': -96.780951},
#   'transactions': [],
#   'location': {'address1': '2933 Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75226',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2933 Main St', 'Dallas, TX 75226']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 6310.762703631428},
#  {'id': 'kAzWiOO57puYDC3BpqTxZA',
#   'alias': 'alice-dallas',
#   'name': 'Alice',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xaphyl-6rGzpYLQjGHNnzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/alice-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 149,
#   'categories': [{'alias': 'panasian', 'title': 'Pan Asian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.7951, 'longitude': -96.78907},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '1623 N Hall St',
#    'address2': 'Ste 103',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75204',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1623 N Hall St', 'Ste 103', 'Dallas, TX 75204']},
#   'phone': '+14698720001',
#   'display_phone': '(469) 872-0001',
#   'distance': 5003.025324499378},
#  {'id': '4oIg7AQRLpsbicCYSLTRTQ',
#   'alias': 'alamo-club-dallas',
#   'name': 'Alamo Club',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9FsK8ev7J7Tw7Q90Q436aA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/alamo-club-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 107,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.814127, 'longitude': -96.770464},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1919 Greenville Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1919 Greenville Ave', 'Dallas, TX 75206']},
#   'phone': '+14693997600',
#   'display_phone': '(469) 399-7600',
#   'distance': 3946.1607525561817},
#  {'id': 'JOZOAXXcOpqL-vGQeEaXfA',
#   'alias': 'zaap-kitchen-lao-and-thai-street-eats-dallas-4',
#   'name': 'ZAAP Kitchen Lao & Thai Street Eats',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Uv8LJzwYooPGhx0DT3zbbw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zaap-kitchen-lao-and-thai-street-eats-dallas-4?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 62,
#   'categories': [{'alias': 'laotian', 'title': 'Laotian'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.8109284483, 'longitude': -96.782231642},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2325 N Fitzhugh',
#    'address2': 'Ste 105',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75204',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2325 N Fitzhugh', 'Ste 105', 'Dallas, TX 75204']},
#   'phone': '+12146132710',
#   'display_phone': '(214) 613-2710',
#   'distance': 3563.5821621754017},
#  {'id': 'DP1I3daE5-mKznnAeA-Q3w',
#   'alias': 'the-woolworth-dallas',
#   'name': 'The Woolworth',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G2edTzjaqJY3UtcqAtb0Ww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-woolworth-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 959,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.781329, 'longitude': -96.798727},
#   'transactions': ['restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1520 Elm St',
#    'address2': 'Ste 201',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75204',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1520 Elm St', 'Ste 201', 'Dallas, TX 75204']},
#   'phone': '+12148140588',
#   'display_phone': '(214) 814-0588',
#   'distance': 6420.165287729477},
#  {'id': 'hIm5FGO8w_an1hJHaFUUWw',
#   'alias': 'san-martín-bakery-and-restaurant-dallas-2',
#   'name': 'San Martín  Bakery & Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aZUCHc_iiaaGJCSk1eOX2Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/san-mart%C3%ADn-bakery-and-restaurant-dallas-2?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 445,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.80218, 'longitude': -96.79993},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3120 McKinney Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75204',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3120 McKinney Ave', 'Dallas, TX 75204']},
#   'phone': '+14698026652',
#   'display_phone': '(469) 802-6652',
#   'distance': 4098.82436140908},
#  {'id': 'RWkDHbSjtgUWkxzMfXvbpw',
#   'alias': 'sabaidee-lao-and-thai-street-food-dallas',
#   'name': 'Sabaidee Lao & Thai Street Food',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V5iMZjfo4l_5bMuuHX9gVw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sabaidee-lao-and-thai-street-food-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 478,
#   'categories': [{'alias': 'laotian', 'title': 'Laotian'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.82559, 'longitude': -96.82099},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '5200 Lemmon Ave',
#    'address2': 'Ste 100',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75209',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5200 Lemmon Ave', 'Ste 100', 'Dallas, TX 75209']},
#   'phone': '+12145206868',
#   'display_phone': '(214) 520-6868',
#   'distance': 2415.3404800058656},
#  {'id': 'KzUVO55qzqrG-TNf2UFGKQ',
#   'alias': 'cafe-izmir-dallas',
#   'name': 'Cafe Izmir',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zgDj1lf_RTwAJQWGywDnvA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cafe-izmir-dallas?adjust_creative=zC-Jrqxt7h6piT-XMntPwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC-Jrqxt7h6piT-XMntPwg',
#   'review_count': 691,
#   'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#    {'alias': 'tapas', 'title': 'Tapas Bars'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.832055, 'longitude': -96.7702649},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3711 Greenville Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Dallas',
#    'zip_code': '75206',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3711 Greenville Ave', 'Dallas, TX 75206']},
#   'phone': '+12148267788',
#   'display_phone': '(214) 826-7788',
#   'distance': 2915.619931370562}]

# %%
# This number includes duplicates
print(len(restaurants_in_dallas))
# Out:
# 200

# %%
# Remove the duplicate entries
res_list = [i for n, i in enumerate(restaurants_in_dallas) if i not in restaurants_in_dallas[n + 1:]]

# %%
len(res_list)
# Out:
# 200

# %%
newlist = sorted(res_list, key=lambda k: k['name'])

# %%
len(newlist)
# Out:
# 200

# %%
restaurants_file = open("restaurants.json", "w")
json.dump(res_list, restaurants_file, indent=6)
restaurants_file.close()
